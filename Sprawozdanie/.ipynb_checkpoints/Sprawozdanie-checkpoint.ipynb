# %% [markdown]
# # Sprawodzanie - mnożenie macierzy

# %% [markdown]
# Kod i wykonanie: Sebastian Kaczor

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Opis maszyny
#
# Parametry komputera którego używałem do obliczeń:
#
# * Procesor Intel Core i7-7700
#    * 4 rdzenie
#    * 4 GHz
#    * Hyper threading wyłączony
#    * Cache
#        * 32KB L1 Data + 32KB L1 Instruction
#        * 256KB L2
#        * 8 MB L3 (współdzielona pomiędzy rdzeniami)
#        * 64B cache line
# * 16GB RAM DDR4
#     * Rozmiar strony 4KB
#     * Data TLB L1: 64 items (na rdzeń)
#     * Data TLB L2: 1536 items (współdzielone)
# * NVIDIA GeForce 1080 Ti
#     * Pamięć 11 GB GDDR5X
#     * 28 SM
#     * 3584 Rdzeni CUDA (128/SM)

# %% [markdown]
# # CPU

# %% [markdown]
# ## Analiza szybkości

# %%
data = pd.read_csv("omp4.csv",index_col=None)
data_jki = data.loc[data['Algorithm']=='JKI']
data_ikj = data.loc[data['Algorithm']=='IKJ']
data_single_core = pd.read_csv("omp1.csv",index_col=None)

# %% [markdown]
# ### Czas mnożenia macierzy w zależności do rozmiaru boku macierzy

# %%
plt.grid(True)
plt.xlabel("Rozmiar boku macierzy")
plt.ylabel("Czas operacji [s]")
plt.scatter(data_jki['Size'], data_jki['Time per test'], label="JKI")
plt.scatter(data_ikj['Size'], data_ikj['Time per test'], label="IKJ")
plt.legend()

# %% [markdown]
# ### Czas obliczania jednego elementu macierzy wyjściowej

# %%
plt.grid(True)
plt.xlabel("Rozmiar boku macierzy")
plt.ylabel("Czas obliczania jednego elementu macierzy wyjściowej [us]")
plt.scatter(data_jki['Size'], data_jki['Time per elem']*1e6, label="JKI")
plt.scatter(data_ikj['Size'], data_ikj['Time per elem']*1e6, label="IKJ")
plt.legend()

# %% [markdown]
# ## To samo, bez ostatniego rozmiaru

# %% [markdown]
# ### Czas mnożenia macierzy w zależności do rozmiaru boku macierzy

# %%
data_jki_filtered = data_jki[:-1] 
data_ikj_filtered = data_ikj[:-1]

# %%
plt.grid(True)
plt.xlabel("Rozmiar boku macierzy")
plt.ylabel("Czas operacji [s]")
plt.scatter(data_jki_filtered['Size'], data_jki_filtered['Time per test'], label="JKI")
plt.scatter(data_ikj_filtered['Size'], data_ikj_filtered['Time per test'], label="IKJ")
plt.legend()

# %% [markdown]
# ### Czas obliczania jednego elementu macierzy wyjściowej

# %%
plt.grid(True)
plt.xlabel("Rozmiar boku macierzy")
plt.ylabel("Czas operacji/element [us]")
plt.scatter(data_jki_filtered['Size'], data_jki_filtered['Time per elem']*1e6, label="JKI")
plt.scatter(data_ikj_filtered['Size'], data_ikj_filtered['Time per elem']*1e6, label="IKJ")
plt.legend()

# %% [markdown]
# ## Analiza maksymalnych osiągnięć

# %% [markdown]
# ### Ilość operacji na sekundę

# %% [markdown]
# Wyliczona jako: $$\frac{2*N^3}{T_{przetwarzania}}$$

# %%
data['Ops per output'] = data['Size']*2
data['Ops per second'] = data['Ops per output']/data['Time per elem']

data_jki = data.loc[data['Algorithm']=='JKI']
data_ikj = data.loc[data['Algorithm']=='IKJ']

# %%
plt.grid(True)
plt.xlabel("Rozmiar boku macierzy")
plt.ylabel("Ilość operacji na sekundę")
plt.scatter(data_jki['Size'], data_jki['Ops per second'], label="JKI")
plt.scatter(data_ikj['Size'], data_ikj['Ops per second'], label="IKJ")
plt.legend()

# %% [markdown]
# Algorytm IJK sprawdza się zdecydowanie lepiej niż algorytm JKI. Wynika to najprawdopodobniej z braku problemów IKJ z lokalnością przestrzenną dostępu.<br><br>
# Algorytm JKI uzyskał bardzo niską szybkość dla rozmiarów 256 i 512. Wynika to prawdopodobnie z niefortunnego ułożenia adresów w pamięci (adres każdego rzędu był większy od poprzedniego o równo 1024/2048 bajtów, przez co prawdopodobnie adresy te mogły zajmować tylko niewielką część z bufora TLB)<br>
# <br>
# Pełna tabela z danymi dostępna na dole sprawozdania.

# %% [markdown]
# ## Porównanie przyśpieszenia

# %% [markdown]
# Przyśpieszenie wyliczane jest jako stosunek szybkości obliczeń przy użyciu 4 rdzeni, a szybkości obliczeń używając tylko 1 rdzenia. <br>
# Przyśpieszenie 4.0 oznaczałoby idealną paralelizację.

# %%
sequential_speed = 1/data_single_core['Time per elem'].values
parallel_speed = 1/data['Time per elem']
#iterative_speeds = np.tile(iterative_speeds.values, (3,1)).swapaxes(0,1).reshape((-1))#repeat each element 3 times
data['Parallel speedup'] = parallel_speed/sequential_speed

#data_speedup_sorted = data[data['Algorithm']!='IJK'].sort_values('Parallel speedup')
data_speedup_sorted = data[['Algorithm', 'Size', 'Parallel speedup']].sort_values('Parallel speedup')

# %% [markdown]
# ### Najgorsze przyśpieszenie
# Dla poniższy rozmiarów nie ma sensu używać algorytów równoleglych, ponieważ powodują spadek szybkości przetwarzania

# %%
data_speedup_sorted.head(6)
# Out:
#   Algorithm  Size  Parallel speedup
# 0       JKI     1          0.028066
# 1       IKJ     1          0.028817
# 2       JKI     2          0.030554
# 3       IKJ     2          0.034621
# 5       IKJ     3          0.042495
# 4       JKI     3          0.043054

# %% [markdown]
# ### Najlepsze przyśpieszenie

# %%
data_speedup_sorted.tail(10)
# Out:
#    Algorithm  Size  Parallel speedup
# 64       JKI   609          3.755314
# 61       IKJ   431          3.775682
# 66       JKI   724          3.776821
# 68       JKI   861          3.783152
# 69       IKJ   861          3.791446
# 72       JKI  1218          3.818502
# 74       JKI  1448          3.835835
# 73       IKJ  1218          3.837206
# 76       JKI  1722          3.839405
# 75       IKJ  1448          3.850346

# %% [markdown]
# Oba algorytmu dla dużych macierzy paralelizują się bardzo dobrze. Używając 4 rdzeni przyśpieszenie dla dużych macierzy jest prawie 4-krotne, czyli nie koszty synchornizacji są niewielkie.

# %% [markdown]
# ### Pełna tabelka przyśpieszeń
# Pełne table z danymi są na końcu sprawozdania.

# %% [markdown]
# ## Analizy lokalności
# Macierze wejściowe A,B<br>
# Macierz wyjściowa C<br>
# Wszystkie macierze są rozmiarów NxN<br>
# W - liczba wątków, W=4
#
#
# ### Algorytm IKJ
# Każdy wątek zajmuje się tworzeniem jednego rzędu macierzy wyjściowej.<br>
# Pamięć czytana jest liniowo zarówno z macierzy A jak i B. <br>
# Macierz C również jest czytana/zapisywania liniowo, ale każdy rząd zostanie odczytany/zapisany N razy.<br>
# Macierze B jest czytana wielokrotnie, co może powodować powoduje brak lokalności czasowej.
#
# ### Algorytm JKI
# Każdy wątek zajmuje się tworzeniem jednej kolumny macierzy wyjściowej.<br>
# Macierz A nie jest czytana liniowo (jest czytana po kolumnach, czyli w skokach o N \* sizeof(float) bajtów). Pamieć B również nie jest czytania liniowo, ale jej odczyty dzieje się raz na N mnożeń, więc nie wprowadza to znaczących kosztów.<br>
# Macierz C również nie jest zapisywana/oczytywania liniowo. W każdej iteracji najbardziej wewnętrznej pętli aktualizowany jest kolejny element kolumny, co powoduje skok o N \* sizeof(flaot) bajtów.<br>
# Macierze C i A są czytane wielokrotnie, co może powodować brak lokalności czasowej.<br>
# Macierze C i A są czytane skokowo, co może powodować brak lokalności przestrzennej.<br>
# ![Obciążenie](img/multiply.jpg)
#
#
#
# ### Analiza warunków lokalnego czasowo dostępu do danych w pamięci podręcznej
# L3 na moim systemie ma rozmiar 8MB<br>
# sizeof(float) = 4B
# #### IKJ
# Potrzeba załadować całą macierz B oraz W wierszy macierzy C<br>
# 8MB = $2^{23}$B -> $2^{21}$ float'ów<br>
# Maksymalne rozmiary macierzy:
# Ilość użytych floatów: $N * N + W * N = N * N + 4 * N =  N(N+4)$<br>
# $ N(N+4) = 2^{21} $ -> $ N = 1446.15$ -> $N = 1446$<br>
# Powyżej N=1446 lokalność czasowa nie jest zapewniona.
# #### JKI
# Potrzeba załadować całą macierz A oraz W wierszy macierzy C<br>
# 8MB = $2^{23}$B -> $2^{21}$ float'ów<br>
# Maksymalne rozmiary macierzy:
# Ilość użytych floatów: $N * N + W * N = N * N + 4 * N =  N(N+4)$<br>
# $ N(N+4) = 2^{21} $ -> $ N = 1446.15$ -> $N = 1446$<br>
# Powyżej N=1446 lokalność czasowa nie jest zapewniona.<br>
# <br>
# Powyżej N=1446 lokalność czasowa nie jest zapewniona w obu metodach.
#
# ### Analiza warunków lokalnego przestrzennie dostępu do danych
# #### IKJ
# Pamięć czytana jest liniowo, bez skoków, więc prblemy z przestrzennym dostępem do danych nie występują.
# #### JKI
# Pamięć czytana jest skokowo, powodując potencjalny brak lokalonści przestrzennej.<br>
# Macierze A, B i C są czytane skokowo, ale interesują nas tylko macierze A i C, ponieważ odczytanie kolejnego elementu w macierzy B zdarza się raz na N iteracji.<br>
# Rozważmy 2 przypadki
# * Rząd zajmuje więcej lub równo pamięci co rozmiar strony
#     * 4KB -> 1024 float'y, czyli dla N>=1024
#     * W L1 TLB mamy miejsce na 64 wpisy, więc skoro N>1024 to na pewno nasza macierz nie zmieści się do TLB
#     * W L2 TLB mamy miejsce na 1536 wpisów. Ponieważ skaczemy szybko po macierzach A i C, to każda z nich może dostać jedynie połowę wpisów. Oznacza to że dla N >= 786 (a właściwie N >= 1024, bo założyliśmy że rząd zajmuje nie mniej niż niż rozmiar strony), adresy przestaną mieścić się w L2 TLB.
#     * Podsumowując: jeśli rząd nie mieści się do jednej strony, to na pewno wszystkie potrzbne adresy nie zmieszczą się to TLB.
# * Rząd zajmuje mniej niż jedną stronę
#     * Dla N < 1024
#     * Ilość stron na macierz: 64 wpisy \* 4 KB (strona) = 256KB -> 128KB na macierz -> 32 * 1024 float'y -> N = 181
#         * Adresy z macierzy o N <= 181 mieszczą się w całości do L1 TLB
#     * Korzystając z L1 TLB i L2 TLS
#        64+1536 wpisów \* 4KB (strona) = 6400KB -> 3200KB na macierz -> 800 * 1024 float'y -> N = 905
#        * Adresy z macierzy o N <= 905 mieszczą się w całości do L2 TLB
#
# #### Ilość operacji na sekundę, wykres powtórzony

# %%
plt.grid(True)
plt.xlabel("Rozmiar boku macierzy")
plt.ylabel("Ilość operacji na sekundę")
plt.scatter(data_jki['Size'], data_jki['Ops per second'], label="JKI")
plt.scatter(data_ikj['Size'], data_ikj['Ops per second'], label="IKJ")
plt.legend()

# %% [markdown]
# ### Warunki lokalności czasowej
# Rozmiarem, który przestawał zapewniać lokalność czasową danych było N = 1446. Możemy zauważyć, że obie metody powyżej tego rozmiaru zwalniają (dużo lepiej jest to widoczne dla algorytmu IKJ, który nia ma problemów z lokalnością przestrzenną)
#
# ### Warunki lokalności przestrzennej
# Możemy zauważyć, że prędkość algorytmu JKI najpierw rośnie (to spodowodowe jest zmnieszaniem kosztów zrównoleglania, które dla małych macierzy są bardzo znaczącee)<br>
# Następnie, w okolicach rozmiaru 200, możemy zauważyć pierwszy spadek szybkości. Pokrywa się z wyliczonym rozmiarem N = 181, kiedy to adresy przestają mieścić się w L1 TLB<br>
# Kolejny, bardzo zauważalny spadek następuje około rozmiaru 1000. Pokyrwa się to z wyliczonym rozmiarem N = 905, kiedy adresy przestają się mieścić w jakimkolwiek TLB.

# %% [markdown]
# ## Równomierność obciążenia
# Zarówno w algorytmie IJK jak i JKI zrównoleglenie następuje po zewnętrznej pętli, odpowiedzialnej za całe kolumny lub rzędy. W najgorszym wypadku pojedyńczy rdzeń może otrzymać jedną kolumnę/rząd więcej lub mniej niż inne. Można więc założyć, że praca rozkładana jest równomiernie.
#
# ### Analiza obciążenia
# Problem: nawet przy macierzach 1 elementowych wszystkie rdzenie są wykorzystywane
# ![Obciążenie](img/1elem4cores.png)
#
# Zamiast mierzyć równomiernosć obciążenia postanowiłem wyznaczyć minimalny rozmiar instancji, który pozwala na wydajne zrównologlenie (50% optymalnego przy 4 rdzeniach)

# %% [markdown]
# ## Analiza wydajności zrównoleglania

# %%
data2 = pd.read_csv("Dane2.csv")
data2 = data2.groupby(['Algorithm', 'Size', 'Num threads'], as_index=False).mean()
data2['Time per core'] = data2['Time[us]'] * data2['Num threads']
multi_threaded = data2.loc[data2['Num threads'] > 1].copy()
single_threaded = data2.loc[data2['Num threads'] == 1].copy()
multi_threaded['Efficiency'] = single_threaded['Time per core'].values/multi_threaded['Time per core'].values
multi_threaded[['Algorithm', 'Size', 'Num threads', 'Efficiency']]
# Out:
#    Algorithm  Size  Num threads  Efficiency
# 1        IKJ     2            2    0.066712
# 3        IKJ    16            4    0.527814
# 5        IKJ    32            4    0.667287
# 7        IKJ    64            4    0.863842
# 9        IKJ   128            4    0.851466
# 11       IKJ   256            4    0.820523
# 13       JKI    16            4    0.043613
# 15       JKI    64            4    0.183335
# 17       JKI   128            4    0.270596
# 19       JKI   256            4    0.707360

# %% [markdown]
# Wyjaśnienie:<br>
# Wydajność (efficiency) na poziomie 1/liczba wątków oznacza, że wprowadzenie wielowątkowości nie przyśpieszyło programu<br>
# Wydajność mniejsza niż 1/liczba wątków oznacza, że wielowątkowość spowolniła działanie programu<br>
# Wydajność bliska 1 oznacza przyśpieszenie bliskie teoretycznemu maksimum<br>
# Wydajność = Przyśpieszenie/Liczba wątków

# %% [markdown]
# * Algorytm IKJ osiąga zadowalający poziom paralelizacji już przy macierzach o rozmiarze 16
# * Algorytm JKI potrzebuje macierzy do tego macierzy o rozmiarze 128-256

# %% [markdown]
# ## Podsumowanie
# Algorytm IKJ jest zdecydowanie szybszy niż algorytm JKI. <br>
# Wynika to z znacznie lepszej lokalności przestrzennej. IKJ czyta wszystkie macierze liniowo, bez żadnych skoków. JKI Czyta dwie macierze skokowo, a na dodatek jedną z nich czyta w ten sposób wielokrotnie. Oznacza to że wzrost rozmiaru macierzy powoduje dla algorytmu JKI coraz większe spowolnienia wynikające z coraz gorszej przestrzennej lokalności (adresy macierzy przestają się mieścić w TBL, więc trzba wykonywać wieloetapowe przeliczanie adresu wirtualnego na rzeczywisty).<br> Dodatkowo wczytywanie skokowe algorytmu JKI powoduje zmarnowanie większości danych wczytanych z linii pamięci cache (używamy tylko 1 floata, czyli 4 bajtów, a wczytujemy 64b), podczas gdy IKJ w dwóch najczęściej czytanych macierzach korzysta w pełni z linii cache.

# %% [markdown]
# # GPU

# %% [markdown]
# ## Analiza ilości dostępów do pamięci dla GPU

# %% [markdown]
# #### Założenia
# * Załóżmy rozmiar boku macierzy: n
# * Założmy rozmiar bloku: b
# * Każdy wątek oblicza 2 elementy
# * Każdy blok oblicza b\*b*2 elementów
#
# Ilość bloków w macierzy wyjściowej: n/b x n/(2\*b)<br>
# Ilość odczytywanych bloków potrzebnych do wyliczenia jednego bloku wyjściowego:  n/b lub n/(2*b)<br>
# Ilość elementów odczytywanych przez blok = ilość wątków w bloku<br>
# Odczytywane są 2 macierze<br>
# Sumaryczna libczba odczytów:
#
# $$({n \over b} * {n \over 2b}) * ( {n \over b} + {n \over 2b} ) * (b*b*2)  =  {n^3 \over b} * (1  + {1 \over 2} )$$

# %%
def reads_blocked(n, b):
    from math import ceil
    return ceil(n/b) * ceil(n/2/b) * ( ceil(n/b) + ceil(n/2/b) ) * b * b * 2
def reads_naive(n):
    return n**3

def gcma(n, reads = None):
    if not reads:
        reads = n**3
    return n**3*2/reads

# %% [markdown]
# Przykładowo dla macierzy o rozmiarze 512 i bloku o rozmiarze 32

# %%
n = 512
b = 32
reads_blocked_val = reads_blocked(n, b)
reads_naive_val = reads_naive(n)
print("Blokowo {}, bez bloków {}, oszczędność {:.4f}".format(reads_blocked_val, reads_naive_val, reads_naive_val/reads_blocked_val))
# Out:
# Blokowo 6291456, bez bloków 134217728, oszczędność 21.3333

# %% [markdown]
# Oszczędność odczytów przekłada się bezpośrednio na ilość dostępów do pamięci globalnej.

# %%
print("CGMA blokowo {:.4f}, bez bloków {:.4f}".format(gcma(n,reads_blocked(n,b)), gcma(n)))
# Out:
# CGMA blokowo 42.6667, bez bloków 2.0000

# %% [markdown]
# ### Szybkość przetwarzania GPU

# %%
data3 = pd.read_csv("Dane3.csv")
data3["Time per test"] = data3['Time']/data3['Iters']
data3["Time per elem"] = data3["Time per test"]/data3['Size']**2
data3['Ops per second'] = 1/data3['Time per elem']*2*data3['Size']
data3.sort_values('Block size', inplace=True)
data3
# Out:
#    Size  Block size  Iters      Time  Time per test  Time per elem  \
# 4  4096           8     20  16.05000       0.802500   4.783273e-08
# 8  2048           8    100   9.62773       0.096277   2.295430e-08
# 3  4096          16     20   6.87242       0.343621   2.048141e-08
# 7  2048          16    100   4.21795       0.042180   1.005638e-08
# 9  4096          24     20   3.92136       0.196068   1.168656e-08
# 1  4096          30     20   3.59133       0.179567   1.070300e-08
# 0  4096          32     20   3.21624       0.160812   9.585142e-09
# 2  4096          32    100  16.08440       0.160844   9.587049e-09
# 5  8192          32     20  25.60860       1.280430   1.907989e-08
# 6  2048          32    100   2.04758       0.020476   4.881811e-09
#
#    Ops per second
# 4    1.712635e+11
# 8    1.784415e+11
# 3    3.999725e+11
# 7    4.073038e+11
# 9    7.009760e+11
# 1    7.653931e+11
# 0    8.546561e+11
# 2    8.544860e+11
# 5    8.587050e+11
# 6    8.390329e+11

# %% [markdown]
# ### Maksymalna ilość operacji

# %%
gpu_max_ops = np.max(data3['Ops per second'].values)
print("Maksymalna wydajność {:.3f} GFLOPS".format((gpu_max_ops*1e-9)))
# Out:
# Maksymalna wydajność 858.705 GFLOPS

# %% [markdown]
# Maksymalna wydajność deklarowana przez Nvidię to 11 000 GFLOPS, ale wymaga ona korzystania z Fused Multiply Add, co nie było częścią tego zadania.

# %% [markdown]
# ### Zajętość multiprocesora
# 50% - Wynik z kalkulatora CUDA (1024 (32x32) wątki na blok, 8GB pamięci współdzielonej, 56 rejestrów).<br>
# Ilość rejestrów stanowi czynnik ograniczający<br>
# Rozmiar bloku 576 (24x24) był sugerowany przez kalkulator jako zapewniający większą zajętość multiprocesora (56%). Widać jednak spowolnienie obliczeń, wynikające z obniżenia GCMA (GCMA spadło o 26%, a zajętość wzrosła o 12% (6 punktów procenowych))

# %% [markdown]
# ### Blok 32x32
# ![Zajętość1024](img/block1024.png)
# ### Blok 24x24
# ![Zajętość576](img/block576.png)

# %% [markdown]
# ### Tabele zbiorcze danych

# %% [markdown]
# #### Tabela ilości operacji na sekundę dla CPU

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', 10):
    display(data[['Algorithm', 'Size', 'Ops per second']])
# Out:
#    Algorithm  Size  Ops per second
# 0        JKI     1    1.587150e+06
# 1        IKJ     1    1.641632e+06
# 2        JKI     2    1.211449e+07
# 3        IKJ     2    1.325803e+07
# 4        JKI     3    4.348771e+07
# 5        IKJ     3    4.093886e+07
# 6        JKI     4    8.031588e+07
# 7        IKJ     4    1.008415e+08
# 8        JKI     5    1.506260e+08
# 9        IKJ     5    1.858905e+08
# 10       JKI     6    2.212752e+08
# 11       IKJ     6    2.913244e+08
# 12       JKI     7    3.326222e+08
# 13       IKJ     7    4.974842e+08
# 14       JKI     8    3.715866e+08
# 15       IKJ     8    7.162779e+08
# 16       JKI    10    5.188202e+08
# 17       IKJ    10    1.169597e+09
# 18       JKI    11    5.610985e+08
# 19       IKJ    11    1.633562e+09
# 20       JKI    13    4.715475e+08
# 21       IKJ    13    2.585367e+09
# 22       JKI    16    4.257170e+08
# 23       IKJ    16    3.458435e+09
# 24       JKI    19    2.522068e+08
# 25       IKJ    19    5.697493e+09
# 26       JKI    23    4.641097e+08
# 27       IKJ    23    6.741063e+09
# 28       JKI    27    4.611837e+08
# 29       IKJ    27    7.485736e+09
# 30       JKI    32    4.818842e+08
# 31       IKJ    32    8.785501e+09
# 32       JKI    38    4.879145e+08
# 33       IKJ    38    1.045069e+10
# 34       JKI    45    5.617136e+08
# 35       IKJ    45    1.359999e+10
# 36       JKI    54    6.379095e+08
# 37       IKJ    54    1.374983e+10
# 38       JKI    64    9.050414e+08
# 39       IKJ    64    1.231563e+10
# 40       JKI    76    1.144837e+09
# 41       IKJ    76    1.251101e+10
# 42       JKI    91    1.632243e+09
# 43       IKJ    91    1.275233e+10
# 44       JKI   108    1.717735e+09
# 45       IKJ   108    1.322104e+10
# 46       JKI   128    1.270125e+09
# 47       IKJ   128    1.263274e+10
# 48       JKI   152    1.179964e+10
# 49       IKJ   152    1.432530e+10
# 50       JKI   181    1.177642e+10
# 51       IKJ   181    1.449775e+10
# 52       JKI   215    1.050433e+10
# 53       IKJ   215    1.384248e+10
# 54       JKI   256    2.426598e+09
# 55       IKJ   256    1.462627e+10
# 56       JKI   304    6.458048e+09
# 57       IKJ   304    1.426303e+10
# 58       JKI   362    7.053643e+09
# 59       IKJ   362    1.438603e+10
# 60       JKI   431    6.441489e+09
# 61       IKJ   431    1.527927e+10
# 62       JKI   512    1.788821e+09
# 63       IKJ   512    1.426239e+10
# 64       JKI   609    6.976145e+09
# 65       IKJ   609    1.527709e+10
# 66       JKI   724    7.348463e+09
# 67       IKJ   724    1.517056e+10
# 68       JKI   861    7.224761e+09
# 69       IKJ   861    1.554208e+10
# 70       JKI  1024    1.078462e+09
# 71       IKJ  1024    1.540475e+10
# 72       JKI  1218    1.039866e+09
# 73       IKJ  1218    1.568203e+10
# 74       JKI  1448    1.019959e+09
# 75       IKJ  1448    1.548514e+10
# 76       JKI  1722    9.659939e+08
# 77       IKJ  1722    1.472531e+10
# 78       JKI  2048    1.515830e+08
# 79       IKJ  2048    1.369987e+10

# %% [markdown]
# #### Tabela przyśpieszeń przy użyciu 4 rdzeni

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', 10):
    display(data_speedup_sorted.sort_values(['Algorithm','Size']))
# Out:
#    Algorithm  Size  Parallel speedup
# 1        IKJ     1          0.028817
# 3        IKJ     2          0.034621
# 5        IKJ     3          0.042495
# 7        IKJ     4          0.059915
# 9        IKJ     5          0.087840
# 11       IKJ     6          0.114104
# 13       IKJ     7          0.170750
# 15       IKJ     8          0.227352
# 17       IKJ    10          0.338358
# 19       IKJ    11          0.488121
# 21       IKJ    13          0.734465
# 23       IKJ    16          0.947243
# 25       IKJ    19          1.501364
# 27       IKJ    23          1.742037
# 29       IKJ    27          1.922905
# 31       IKJ    32          2.207467
# 33       IKJ    38          2.629778
# 35       IKJ    45          3.402310
# 37       IKJ    54          3.387157
# 39       IKJ    64          3.026123
# 41       IKJ    76          3.374803
# 43       IKJ    91          3.389605
# 45       IKJ   108          3.458941
# 47       IKJ   128          3.299376
# 49       IKJ   152          3.675777
# 51       IKJ   181          3.685018
# 53       IKJ   215          3.486663
# 55       IKJ   256          3.750125
# 57       IKJ   304          3.542908
# 59       IKJ   362          3.553588
# 61       IKJ   431          3.775682
# 63       IKJ   512          3.495331
# 65       IKJ   609          3.743377
# 67       IKJ   724          3.703912
# 69       IKJ   861          3.791446
# 71       IKJ  1024          3.738375
# 73       IKJ  1218          3.837206
# 75       IKJ  1448          3.850346
# 77       IKJ  1722          3.701983
# 79       IKJ  2048          3.433730
# 0        JKI     1          0.028066
# 2        JKI     2          0.030554
# 4        JKI     3          0.043054
# 6        JKI     4          0.046214
# 8        JKI     5          0.069703
# 10       JKI     6          0.083021
# 12       JKI     7          0.110538
# 14       JKI     8          0.114325
# 16       JKI    10          0.145618
# 18       JKI    11          0.163668
# 20       JKI    13          0.132266
# 22       JKI    16          0.114090
# 24       JKI    19          0.066591
# 26       JKI    23          0.118863
# 28       JKI    27          0.117339
# 30       JKI    32          0.121317
# 32       JKI    38          0.122388
# 34       JKI    45          0.138819
# 36       JKI    54          0.157284
# 38       JKI    64          0.223405
# 40       JKI    76          0.309144
# 42       JKI    91          0.398149
# 44       JKI   108          0.450141
# 46       JKI   128          1.286671
# 48       JKI   152          3.030155
# 50       JKI   181          3.050339
# 52       JKI   215          3.460590
# 54       JKI   256          3.269779
# 56       JKI   304          3.116858
# 58       JKI   362          3.559177
# 60       JKI   431          3.621417
# 62       JKI   512          3.701078
# 64       JKI   609          3.755314
# 66       JKI   724          3.776821
# 68       JKI   861          3.783152
# 70       JKI  1024          3.748678
# 72       JKI  1218          3.818502
# 74       JKI  1448          3.835835
# 76       JKI  1722          3.839405
# 78       JKI  2048          1.145921
